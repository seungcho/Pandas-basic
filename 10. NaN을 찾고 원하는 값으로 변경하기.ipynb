# %%
import pandas as pd

# %%
school_id_list = [{'name': 'John', 'job': "teacher", 'age': 40},
                {'name': 'Nate', 'job': "teacher", 'age': 35},
                {'name': 'Yuna', 'job': "teacher", 'age': 37},
                {'name': 'Abraham', 'job': "student", 'age': 10},
                {'name': 'Brian', 'job': "student", 'age': 12},
                {'name': 'Janny', 'job': "student", 'age': 11},
                {'name': 'Nate', 'job': "teacher", 'age': None},
                {'name': 'John', 'job': "student", 'age': None}
         ]
df = pd.DataFrame(school_id_list, columns = ['name', 'job', 'age'])

# %%
df # 6,7번째 index None 값 발견
# Out:
#       name      job   age
# 0     John  teacher  40.0
# 1     Nate  teacher  35.0
# 2     Yuna  teacher  37.0
# 3  Abraham  student  10.0
# 4    Brian  student  12.0
# 5    Janny  student  11.0
# 6     Nate  teacher   NaN
# 7     John  student   NaN

# %%
df.shape # (8,3)
# Out:
# (8, 3)

# %%
df.info() # age에서 2개의 None 값 발견
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
# name    8 non-null object
# job     8 non-null object
# age     6 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 272.0+ bytes

# %%
df.isnull() # True 값들을 null값
# Out:
#     name    job    age
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False
# 4  False  False  False
# 5  False  False  False
# 6  False  False   True
# 7  False  False   True

# %%
df['age'] = df['age'].fillna(0) # age 모든 헹의 결측값을 0으로 대체

# %%
df
# Out:
#       name      job   age
# 0     John  teacher  40.0
# 1     Nate  teacher  35.0
# 2     Yuna  teacher  37.0
# 3  Abraham  student  10.0
# 4    Brian  student  12.0
# 5    Janny  student  11.0
# 6     Nate  teacher   0.0
# 7     John  student   0.0

# %%
df = pd.DataFrame(school_id_list, columns = ['name', 'job', 'age'])

# %%
df
# Out:
#       name      job   age
# 0     John  teacher  40.0
# 1     Nate  teacher  35.0
# 2     Yuna  teacher  37.0
# 3  Abraham  student  10.0
# 4    Brian  student  12.0
# 5    Janny  student  11.0
# 6     Nate  teacher   NaN
# 7     John  student   NaN

# %%
df['age'].fillna(df.groupby('job')['age'].transform('median'),inplace = True)
# Job으로 groupby 하여 선생님과 학생을 구분하고 age값을 구분한 중간값으로 변경한다.

# %%
df
# Out:
#       name      job   age
# 0     John  teacher  40.0
# 1     Nate  teacher  35.0
# 2     Yuna  teacher  37.0
# 3  Abraham  student  10.0
# 4    Brian  student  12.0
# 5    Janny  student  11.0
# 6     Nate  teacher  37.0
# 7     John  student  11.0
